# %%
import requests

import pandas as pd

from bs4 import BeautifulSoup

from lxml import etree

# %%
url = 'https://pythonwheels.com/'
response = requests.get(url)

# %%
with open('Python-Wheels.html') as f:
    content = f.read()
    soup = BeautifulSoup(content, 'html.parser')

# %%
for span in soup.find_all('span', {'class' :"ng-binding"}):
    if span.get_text() !='✓':
        print(span.get_text())
# Out:
# boto3
# urllib3
# botocore
# requests
# certifi
# typing-extensions
# idna
# charset-normalizer
# python-dateutil
# setuptools
# packaging
# s3transfer
# aiobotocore
# wheel
# pyyaml
# six
# grpcio-status
# pip
# numpy
# s3fs
# fsspec
# cryptography
# cffi
# google-api-core
# pycparser
# pandas
# importlib-metadata
# pyasn1
# rsa
# zipp
# click
# pydantic
# attrs
# protobuf
# jmespath
# platformdirs
# pytz
# jinja2
# awscli
# colorama
# markupsafe
# pyjwt
# tomli
# googleapis-common-protos
# wrapt
# filelock
# cachetools
# google-auth
# pluggy
# requests-oauthlib
# virtualenv
# pytest
# oauthlib
# pyarrow
# docutils
# exceptiongroup
# pyasn1-modules
# jsonschema
# iniconfig
# scipy
# pyparsing
# aiohttp
# isodate
# soupsieve
# sqlalchemy
# beautifulsoup4
# psutil
# pydantic-core
# pygments
# multidict
# pyopenssl
# yarl
# decorator
# tzdata
# async-timeout
# tqdm
# grpcio
# frozenlist
# pillow
# aiosignal
# greenlet
# openpyxl
# et-xmlfile
# requests-toolbelt
# annotated-types
# lxml
# tomlkit
# werkzeug
# proto-plus
# pynacl
# deprecated
# azure-core
# asn1crypto
# distlib
# importlib-resources
# coverage
# more-itertools
# google-cloud-storage
# websocket-client
# h11
# sniffio
# pexpect
# ptyprocess
# msgpack
# google-cloud-core
# python-dotenv
# anyio
# flask
# rpds-py
# scikit-learn
# referencing
# typedload
# google-resumable-media
# chardet
# psycopg2-binary
# jsonschema-specifications
# backoff
# msal
# tenacity
# poetry-plugin-export
# tabulate
# matplotlib
# poetry-core
# httpcore
# pathspec
# rich
# py
# httpx
# bcrypt
# wcwidth
# mypy-extensions
# dill
# sortedcontainers
# gitpython
# paramiko
# shellingham
# threadpoolctl
# itsdangerous
# snowflake-connector-python
# markdown-it-py
# keyring
# regex
# google-crc32c
# azure-storage-blob
# mdurl
# smmap
# ruamel-yaml
# gitdb
# kiwisolver
# networkx
# cycler
# py4j
# portalocker
# google-auth-oauthlib
# awswrangler
# joblib
# pytest-cov
# fastjsonschema
# secretstorage
# pkginfo
# jaraco-classes
# jeepney
# future
# grpcio-tools
# build
# sqlparse
# fonttools
# msal-extensions
# google-cloud-bigquery
# pymysql
# trove-classifiers
# prompt-toolkit
# pyproject-hooks
# rapidfuzz
# cloudpickle
# xmltodict
# dnspython
# azure-identity
# google-api-python-client
# nest-asyncio
# tzlocal
# marshmallow
# distro
# scramp
# docker
# ruamel-yaml-clib
# toml
# cython
# mccabe
# defusedxml
# uritemplate
# cachecontrol
# ipython
# pyrsistent
# huggingface-hub
# termcolor
# traitlets
# httplib2
# google-auth-httplib2
# blinker
# pendulum
# ply
# markdown
# babel
# poetry
# alembic
# requests-aws4auth
# pycodestyle
# gunicorn
# redis
# tornado
# pygithub
# contourpy
# isort
# msrest
# azure-common
# crashtest
# types-requests
# redshift-connector
# jedi
# retry
# datadog
# dulwich
# jsonpointer
# grpc-google-iam-v1
# pycryptodomex
# cleo
# parso
# webencodings
# matplotlib-inline
# pg8000
# pytzdata
# fastapi
# installer
# jsonpath-ng
# opentelemetry-api
# tb-nightly
# prometheus-client
# black
# pytest-runner
# loguru
# toolz
# pycryptodome
# python-json-logger
# pyzmq
# pkgutil-resolve-name
# kubernetes
# mako
# typer
# sentry-sdk
# pyspark
# ✗
# multiprocess
# websockets
# argcomplete
# arrow
# transformers
# google-pasta
# asttokens
# opensearch-py
# opentelemetry-sdk
# jsonpatch
# progressbar2
# executing
# jupyter-core
# orjson
# typing-inspect
# google-cloud-pubsub
# setuptools-scm
# pymongo
# aioitertools
# stack-data
# jupyter-client
# torch
# pure-eval
# uvicorn
# pyflakes
# nbconvert
# aenum
# oscrypto
# opentelemetry-semantic-conventions
# starlette
# asgiref
# elasticsearch
# shapely
# python-utils
# tensorboard
# ipykernel
# debugpy
# apache-airflow
# jupyter-server
# types-python-dateutil
# flake8
# google-cloud-secret-manager
# tokenizers
# nbformat
# pyodbc
# requests-file
# notebook
# sagemaker
# snowflake-sqlalchemy
# absl-py
# structlog
# smart-open
# pylint
# mysql-connector-python
# adal
# xlrd
# openai
# sympy
# humanfriendly
# pysocks
# astroid
# zope-interface
# monotonic
# mistune
# rfc3339-validator
# bleach
# tinycss2
# imageio
# comm
# xlsxwriter
# typeguard
# cattrs
# click-man
# asynctest
# jupyterlab-server
# pbr
# mpmath
# h5py
# altair
# tensorflow
# sentencepiece
# jupyterlab
# slack-sdk
# text-unidecode
# argon2-cffi
# nbclient
# google-cloud-bigquery-storage
# gremlinpython
# xgboost
# send2trash
# croniter
# nodeenv
# email-validator
# watchdog
# pytest-xdist
# argon2-cffi-bindings
# oauth2client
# execnet
# flatbuffers
# nltk
# simplejson
# appdirs
# google-cloud-aiplatform
# ujson
# google-cloud-appengine-logging
# python-slugify
# dataclasses-json
# great-expectations
# overrides
# Friday, 30 August 2024, 10:02:32 UTC
